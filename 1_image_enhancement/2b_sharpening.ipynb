# %%
from lib.widgets import (
    interact_laplacian_kernel,
    interact_sharpening_kernel,
    interact_unsharp_mask,
    interact_DoG,
    interact_sharpening_with_noise,
)
from lib.denoising_sharpening import (
    apply_laplacian_kernel,
    apply_sharpening_kernel,
    apply_unsharp_mask,
    apply_DoG,
)
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('data/verona_color.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# # Laplacian
#
# Highlights edges

# %%
new_img = apply_laplacian_kernel(img)
plt.imshow(new_img)

# %% [markdown]
# # Sharpening filter

# %%
new_img = apply_sharpening_kernel(img)
plt.imshow(new_img)

# %% [markdown]
# # Unsharp mask

# %%
new_img = apply_unsharp_mask(img, size=9)
plt.imshow(new_img)

# %% [markdown]
# # Sharpening comparison

# %%
interact_sharpening_with_noise()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_color.jpg', 'data/verona_gray.jpg…
