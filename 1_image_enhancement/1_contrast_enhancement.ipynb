# %% [markdown]
# # Image representation

# %%
from lib.widgets import interact_img_repr

# %%
interact_img_repr()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_bw.png', 'data/verona_color.jpg',…

# %% [markdown]
# # Image histogram

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img_bw = cv2.imread('data/verona_bw.png', cv2.IMREAD_GRAYSCALE)

fig_bw, ax_bw = plt.subplots()
ax_bw.hist(img_bw.flatten(), bins=256, color='black');

# %%
img_gray = cv2.imread('data/verona_gray.jpg', cv2.IMREAD_GRAYSCALE)

fig_gray, ax_gray = plt.subplots()
ax_gray.hist(img_gray.flatten(), bins=256, color='black');

# %%
img_color = cv2.imread('data/verona_color.jpg')

fig_color, axes_color = plt.subplots(ncols=3, figsize=(3*6, 4), sharey=True)

# WARNING! OpenCV reads image default in "BGR"-mode, not "RGB"!

axes_color[0].hist(img_color[..., 2].flatten(), bins=256, color='red')
axes_color[1].hist(img_color[..., 1].flatten(), bins=256, color='green')
axes_color[2].hist(img_color[..., 0].flatten(), bins=256, color='blue');

# %% [markdown]
# We have written our own reusable function to plot image histograms. However, **it expects RGB-images, not BGR-images**, so make sure to do the conversion from BGR to RGB!

# %%
from lib.plots import plot_img_hist

plot_img_hist(cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB))

# %% [markdown]
# It also works with gray-scale images!

# %%
plot_img_hist(img_gray)

# %% [markdown]
# # Linear contrast enhancement

# %%
from lib.contrast_enhance import linear_contrast_enhance

img = cv2.imread('data/verona_color.jpg')
img = img[..., ::-1]  # Shorthand for cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

new_img = linear_contrast_enhance(img, alpha=3.0, beta=50)

plt.imshow(new_img)

# %%
from lib.widgets import interact_linear_contrast_enhance

interact_linear_contrast_enhance()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_color.jpg', 'data/verona_gray.jpg…

# %% [markdown]
# # Gamma correction

# %%
from lib.contrast_enhance import gamma_correct

new_img = gamma_correct(img, gamma=0.5)

fig, ax = plt.subplots()
ax.imshow(new_img)

# %%
from lib.widgets import interact_gamma_correct

interact_gamma_correct()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_color.jpg', 'data/verona_gray.jpg…

# %% [markdown]
# # Histogram equalization

# %%
from lib.contrast_enhance import hist_equalize

new_img = hist_equalize(img)

# %%
plt.imshow(new_img)

# %%
from lib.widgets import interact_hist_equalize

interact_hist_equalize()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_color.jpg', 'data/verona_gray.jpg…

# %% [markdown]
# # Contrast-limited adaptive histogram equalization (CLAHE)

# %%
from lib.contrast_enhance import clahe

new_img = clahe(img)

plt.imshow(new_img)

# %%
from lib.widgets import interact_clahe

interact_clahe()
# Out:
# interactive(children=(Dropdown(description='img_file', options=('data/verona_color.jpg', 'data/verona_gray.jpg…
